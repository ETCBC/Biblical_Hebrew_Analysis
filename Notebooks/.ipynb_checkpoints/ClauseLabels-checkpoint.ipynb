# %% [markdown]
# # Clause Type Labels

# %%
# %%html
# <style>
#
# table.presentation, table.presentation td {
#     border-style:hidden;
#     color: Maroon;
# }
#
# table.presentation td {
#     padding:0px 15px 0px 0px;
# }
#
# table.presentation td.outer {
#     vertical-align:top;
# }
#
# span.hebrew {
#     text-align:right;
#     font-family:SBL Hebrew;
# }
# </style>
# Out:
# <style>
#
# table.presentation, table.presentation td {
#     border-style:hidden;
#     color: Maroon;
# }
#
# table.presentation td {
#     padding:0px 15px 0px 0px;
# }
#
# table.presentation td.outer {
#     vertical-align:top;
# }
#
# span.hebrew {
#     text-align:right;
#     font-family:SBL Hebrew;
# }
# </style>

# %% [markdown]
# <p>The type of a clause depends, in first instance, on the presence of a verbal form in the clause. If such a verbal form is absent,
# but the clause <em>does</em> contain a predicate, the clause is of a nominal kind and can be either a simple nominal clause (if the predicate
# is a noun phrase) - <strong>NmCl</strong> - or an adjective clause (if the predicate is an adjective phrase) - <strong>AjCl</strong>.</p>
#
# <p>We distinguish between the following types of clauses without a predicate:</p>
# <table class="presentation">
# <tr><td>Vocative clause</td><td><strong>Voct</strong></td></tr>
# <tr><td>Casus Pendens</td><td><strong>CPen</strong></td></tr>
# <tr><td>Ellipsis</td><td><strong>Ellp</strong></td></tr>
# <tr><td>Macrosyntactic signal</td><td><strong>MSyn</strong></td></tr>
# <tr><td>Extraposition</td><td><strong>XPos</strong></td></tr>
# </table>
#
# <p>The clause type of verbal clauses is determined by four factors:</p>
# <ul>
# <li>the presence of a coordinating conjunction (<span class="hebrew">&#1493;</span>)</li>
# <li>the presence of constituents that precede the predicate (indicated by small or capital <strong>x/X</strong>)</li>
# <li>the verbal tense of the predicate, which can be either imperative, imperfect (<em>yiqtol</em>), perfect (<em>qatal</em>), or participle</li>
# <li>the presence of an explicit subject (indicated by a capital <strong>X</strong>)</li>
# </ul>
#
# <p>In case of verbal clauses containing an infinite verb form, only the third factor (i.e.: the verbal tense of the predicate), is decisive for
# the clause type of the clause. Thus, the following non-finite clause types can be identified:</p>
# <table class="presentation">
# <tr><td>Participle clause (both participle active and participle passive)</td><td><strong>Ptcp</strong></td></tr>
# <tr><td>Infinitive construct clause</td><td><strong>InfC</strong></td></tr>
# <tr><td>Infinitive absolute clause</td><td><strong>InfA</strong></td></tr>
# </table>
#
# <p>For the verbal clauses containing a finite verb form, the following possible combinations of the four factors are attested in our data:</p>
# <table class="presentation">
# <tr>
# <td class="outer">
# <table class="presentation">
# <tr><td>&#8709;-yiqtol-&#8709;</td><td><strong>ZYq0</strong></td></tr>
# <tr><td>&#8709;-yiqtol-subject</td><td><strong>ZYqX</strong></td></tr>
# <tr><td>&#8709;-qatal-&#8709;</td><td><strong>ZQt0</strong></td></tr>
# <tr><td>&#8709;-qatal-subject</td><td><strong>ZQtX</strong></td></tr>
# <tr><td>&#8709;-imperative-&#8709;</td><td><strong>ZIm0</strong></td></tr>
# <tr><td>&#8709;-imperative-subject</td><td><strong>ZImX</strong></td></tr>
# <tr><td>&nbsp;</td><td>&nbsp;</td></tr>
# <tr><td>subject-yiqtol</td><td><strong>XYqt</strong></td></tr>
# <tr><td>subject-constituent-yiqtol</td><td><strong>XxYq</strong></td></tr>
# <tr><td>constituent-subject-yiqtol</td><td><strong>xXYq</strong></td></tr>
# <tr><td>subject-qatal</td><td><strong>XQtl</strong></td></tr>
# <tr><td>subject-constituent-qatal</td><td><strong>XxQt</strong></td></tr>
# <tr><td>constituent-subject-qatal</td><td><strong>xXQt</strong></td></tr>
# <tr><td>subject-imperative</td><td><strong>XImp</strong></td></tr>
# <tr><td>&nbsp;</td><td>&nbsp;</td></tr>
# </table>
# </td>
# <td class="outer">
# <table class="presentation">
# <tr><td>constituent-yiqtol-&#8709;</td><td><strong>xYq0</strong></td></tr>
# <tr><td>constituent-yiqtol-subject</td><td><strong>xYqX</strong></td></tr>
# <tr><td>constituent-qatal-&#8709;</td><td><strong>xQt0</strong></td></tr>
# <tr><td>constituent-qatal-subject</td><td><strong>xQtX</strong></td></tr>
# <tr><td>constituent-imperative-&#8709;</td><td><strong>xIm0</strong></td></tr>
# <tr><td>constituent-imperative-subject</td><td><strong>xImX</strong></td></tr>
# <tr><td>&nbsp;</td><td>&nbsp;</td></tr>
# <tr><td><span class="hebrew">&#1493;</span>-&#8709;-yiqtol-&#8709;</td><td><strong>WYq0</strong></td></tr>
# <tr><td><span class="hebrew">&#1493;</span>-&#8709;-yiqtol-subject</td><td><strong>WYqX</strong></td></tr>
# <tr><td><span class="hebrew">&#1493;</span>-&#8709;-qatal-&#8709;</td><td><strong>WQt0</strong></td></tr>
# <tr><td><span class="hebrew">&#1493;</span>-&#8709;-qatal-subject</td><td><strong>WQtX</strong></td></tr>
# <tr><td><span class="hebrew">&#1493;</span>-&#8709;-imperative-&#8709;</td><td><strong>WIm0</strong></td></tr>
# <tr><td><span class="hebrew">&#1493;</span>-&#8709;-imperative-subject</td><td><strong>WImX</strong></td></tr>
# <tr><td>wayyiqtol-&#8709;</td><td><strong>Way0</strong></td></tr>
# <tr><td>wayyiqtol-subject</td><td><strong>WayX</strong></td></tr>
# <tr><td>&nbsp;</td><td>&nbsp;</td></tr>
# </table>
# </td>
# <td class="outer">
# <table class="presentation">
# <tr><td><span class="hebrew">&#1493;</span>-subject-yiqtol</td><td><strong>WXYq</strong></td></tr>
# <tr><td><span class="hebrew">&#1493;</span>-subject-constituent-yiqtol</td><td><strong>WXxY</strong></td></tr>
# <tr><td><span class="hebrew">&#1493;</span>-constituent-subject-yiqtol</td><td><strong>WxXY</strong></td></tr>
# <tr><td><span class="hebrew">&#1493;</span>-subject-qatal</td><td><strong>WXQt</strong></td></tr>
# <tr><td><span class="hebrew">&#1493;</span>-subject-constituent-qatal</td><td><strong>WXxQ</strong></td></tr>
# <tr><td><span class="hebrew">&#1493;</span>-constituent-subject-qatal</td><td><strong>WxXQ</strong></td></tr>
# <tr><td><span class="hebrew">&#1493;</span>-subject-imperative</td><td><strong>WXIm</strong></td></tr>
# <tr><td>&nbsp;</td><td>&nbsp;</td></tr>
# <tr><td><span class="hebrew">&#1493;</span>-constituent-yiqtol-&#8709;</td><td><strong>WxY0</strong></td></tr>
# <tr><td><span class="hebrew">&#1493;</span>-constituent-yiqtol-subject</td><td><strong>WxYX</strong></td></tr>
# <tr><td><span class="hebrew">&#1493;</span>-constituent-qatal-&#8709;</td><td><strong>WxQ0</strong></td></tr>
# <tr><td><span class="hebrew">&#1493;</span>-constituent-qatal-subject</td><td><strong>WxQX</strong></td></tr>
# <tr><td><span class="hebrew">&#1493;</span>-constituent-imperative-&#8709;</td><td><strong>WxI0</strong></td></tr>
# <tr><td><span class="hebrew">&#1493;</span>-constituent-imperative-subject</td><td><strong>WxIX</strong></td></tr>
# </table>
# </td>
# </tr>
# </table>
#
# <p>
# If one places the cursor on one of the clausetype labels presented in the 'ClauseType' column of a given Psalm, information pops up about the default discourse functions of the specific clausetype. For more information on these default functions, click
# <a href="DefaultDiscourseFunctions.ipynb" target="_blank">here</a>.
# </p>
